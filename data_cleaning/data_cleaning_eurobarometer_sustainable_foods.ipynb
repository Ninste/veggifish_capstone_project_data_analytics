# %% [markdown]
# # Frage: Deutschland in als Spalte Gesamt, Ost und West vorhanden. Beibehalten?

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import sqlalchemy as sf

# %%
from sql_functions import get_engine
from sql_functions import get_dataframe
from sql_functions import get_sql_config

# %% [markdown]
# # Step 1: Import file and create dataframe with individual variable

# %%
eurobarometer_sustainable_food = pd.read_excel("data/Ernährungsweisen_data/Eurobarometer_Sustainable_Foods_edited.xlsx - Summary.xlsx")

# %%
eurobarometer_sustainable_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   questions  53 non-null     object
#  1   responses  53 non-null     object
#  2   EU 27      53 non-null     float64
#  3   BE         52 non-null     float64
#  4   BG         53 non-null     float64
#  5   CZ         53 non-null     float64
#  6   DK         53 non-null     float64
#  7   D-W        53 non-null     float64
#  8   DE         53 non-null     float64
#  9   D-E        53 non-null     float64
#  10  EE         53 non-null     float64
#  11  IE         53 non-null     float64
#  12  EL         53 non-null     float64
#  13  ES         53 non-null     float64
#  14  FR         53 non-null     float64
#  15  HR         53 non-null     float64
#  16  IT         53 non-null     float64
#  17  CY         52 non-null     float64
#  18  LV         53 non-null     float64
# ...

# %% [markdown]
# # Step 4: Rename columns lower case, snake case, spaces, delimiters

# %%
#Create a dictionary for counrties
counrty_dict = {
"D-W":"West_Germany",
"D-E":"East_Germany",
"AF":"Afghanistan",
"AX":"Aland Islands",
"AL":"Albania",
"DZ":"Algeria",
"AS":"American Samoa",
"AD":"Andorra",
"AO":"Angola",
"AI":"Anguilla",
"AQ":"Antarctica",
"AG":"Antigua and Barbuda",
"AR":"Argentina",
"AM":"Armenia",
"AW":"Aruba",
"AU":"Australia",
"AT":"Austria",
"AZ":"Azerbaijan",
"BS":"Bahamas",
"BH":"Bahrain",
"BD":"Bangladesh",
"BB":"Barbados",
"BY":"Belarus",
"BE":"Belgium",
"BZ":"Belize",
"BJ":"Benin",
"BM":"Bermuda",
"BT":"Bhutan",
"BO":"Bolivia, Plurinational State of",
"BQ":"Bonaire, Sint Eustatius and Saba",
"BA":"Bosnia and Herzegovina",
"BW":"Botswana",
"BV":"Bouvet Island",
"BR":"Brazil",
"IO":"British Indian Ocean Territory",
"BN":"Brunei Darussalam",
"BG":"Bulgaria",
"BF":"Burkina Faso",
"BI":"Burundi",
"KH":"Cambodia",
"CM":"Cameroon",
"CA":"Canada",
"CV":"Cape Verde",
"KY":"Cayman Islands",
"CF":"Central African Republic",
"TD":"Chad",
"CL":"Chile",
"CN":"China",
"CX":"Christmas Island",
"CC":"Cocos (Keeling) Islands",
"CO":"Colombia",
"KM":"Comoros",
"CG":"Congo",
"CD":"Congo, The Democratic Republic of the",
"CK":"Cook Islands",
"CR":"Costa Rica",
"CI":"Côte d'Ivoire",
"HR":"Croatia",
"CU":"Cuba",
"CW":"Curaçao",
"CY":"Cyprus",
"CZ":"Czech Republic",
"DK":"Denmark",
"DJ":"Djibouti",
"DM":"Dominica",
"DO":"Dominican Republic",
"EC":"Ecuador",
"EG":"Egypt",
"SV":"El Salvador",
"GQ":"Equatorial Guinea",
"ER":"Eritrea",
"EE":"Estonia",
"ET":"Ethiopia",
"FK":"Falkland Islands (Malvinas)",
"FO":"Faroe Islands",
"FJ":"Fiji",
"FI":"Finland",
"FR":"France",
"GF":"French Guiana",
"PF":"French Polynesia",
"TF":"French Southern Territories",
"GA":"Gabon",
"GM":"Gambia",
"GE":"Georgia",
"DE":"Germany",
"GH":"Ghana",
"GI":"Gibraltar",
"EL":"Greece",
"GL":"Greenland",
"GD":"Grenada",
"GP":"Guadeloupe",
"GU":"Guam",
"GT":"Guatemala",
"GG":"Guernsey",
"GN":"Guinea",
"GW":"Guinea-Bissau",
"GY":"Guyana",
"HT":"Haiti",
"HM":"Heard Island and McDonald Islands",
"VA":"Holy See (Vatican City State)",
"HN":"Honduras",
"HK":"Hong Kong",
"HU":"Hungary",
"IS":"Iceland",
"IN":"India",
"ID":"Indonesia",
"IR":"Iran, Islamic Republic of",
"IQ":"Iraq",
"IE":"Ireland",
"IM":"Isle of Man",
"IL":"Israel",
"IT":"Italy",
"JM":"Jamaica",
"JP":"Japan",
"JE":"Jersey",
"JO":"Jordan",
"KZ":"Kazakhstan",
"KE":"Kenya",
"KI":"Kiribati",
"KP":"Korea, Democratic People's Republic of",
"KR":"Korea, Republic of",
"KW":"Kuwait",
"KG":"Kyrgyzstan",
"LA":"Lao People's Democratic Republic",
"LV":"Latvia",
"LB":"Lebanon",
"LS":"Lesotho",
"LR":"Liberia",
"LY":"Libya",
"LI":"Liechtenstein",
"LT":"Lithuania",
"LU":"Luxembourg",
"MO":"Macao",
"MK":"Macedonia, Republic of",
"MG":"Madagascar",
"MW":"Malawi",
"MY":"Malaysia",
"MV":"Maldives",
"ML":"Mali",
"MT":"Malta",
"MH":"Marshall Islands",
"MQ":"Martinique",
"MR":"Mauritania",
"MU":"Mauritius",
"YT":"Mayotte",
"MX":"Mexico",
"FM":"Micronesia, Federated States of",
"MD":"Moldova, Republic of",
"MC":"Monaco",
"MN":"Mongolia",
"ME":"Montenegro",
"MS":"Montserrat",
"MA":"Morocco",
"MZ":"Mozambique",
"MM":"Myanmar",
"NA":"Namibia",
"NR":"Nauru",
"NP":"Nepal",
"NL":"Netherlands",
"NC":"New Caledonia",
"NZ":"New Zealand",
"NI":"Nicaragua",
"NE":"Niger",
"NG":"Nigeria",
"NU":"Niue",
"NF":"Norfolk Island",
"MP":"Northern Mariana Islands",
"NO":"Norway",
"OM":"Oman",
"PK":"Pakistan",
"PW":"Palau",
"PS":"Palestinian Territory, Occupied",
"PA":"Panama",
"PG":"Papua New Guinea",
"PY":"Paraguay",
"PE":"Peru",
"PH":"Philippines",
"PN":"Pitcairn",
"PL":"Poland",
"PT":"Portugal",
"PR":"Puerto Rico",
"QA":"Qatar",
"RE":"Réunion",
"RO":"Romania",
"RU":"Russian Federation",
"RW":"Rwanda",
"BL":"Saint Barthélemy",
"SH":"Saint Helena, Ascension and Tristan da Cunha",
"KN":"Saint Kitts and Nevis",
"LC":"Saint Lucia",
"MF":"Saint Martin (French part)",
"PM":"Saint Pierre and Miquelon",
"VC":"Saint Vincent and the Grenadines",
"WS":"Samoa",
"SM":"San Marino",
"ST":"Sao Tome and Principe",
"SA":"Saudi Arabia",
"SN":"Senegal",
"RS":"Serbia",
"SC":"Seychelles",
"SL":"Sierra Leone",
"SG":"Singapore",
"SX":"Sint Maarten (Dutch part)",
"SK":"Slovakia",
"SI":"Slovenia",
"SB":"Solomon Islands",
"SO":"Somalia",
"ZA":"South Africa",
"GS":"South Georgia and the South Sandwich Islands",
"ES":"Spain",
"LK":"Sri Lanka",
"SD":"Sudan",
"SR":"Suriname",
"SS":"South Sudan",
"SJ":"Svalbard and Jan Mayen",
"SZ":"Swaziland",
"SE":"Sweden",
"CH":"Switzerland",
"SY":"Syrian Arab Republic",
"TW":"Taiwan, Province of China",
"TJ":"Tajikistan",
"TZ":"Tanzania, United Republic of",
"TH":"Thailand",
"TL":"Timor-Leste",
"TG":"Togo",
"TK":"Tokelau",
"TO":"Tonga",
"TT":"Trinidad and Tobago",
"TN":"Tunisia",
"TR":"Turkey",
"TM":"Turkmenistan",
"TC":"Turks and Caicos Islands",
"TV":"Tuvalu",
"UG":"Uganda",
"UA":"Ukraine",
"AE":"United Arab Emirates",
"GB":"United Kingdom",
"US":"United States",
"UM":"United States Minor Outlying Islands",
"UY":"Uruguay",
"UZ":"Uzbekistan",
"VU":"Vanuatu",
"VE":"Venezuela, Bolivarian Republic of",
"VN":"Viet Nam",
"VG":"Virgin Islands, British",
"VI":"Virgin Islands, U.S.",
"WF":"Wallis and Futuna",
"YE":"Yemen",
"ZM":"Zambia",
"ZW":"Zimbabwe"}

# %%
# Fill columnnames with countrynames
eurobarometer_sustainable_food = eurobarometer_sustainable_food.rename(columns = counrty_dict)

# %%
eurobarometer_sustainable_food.columns
# Out:
# Index(['questions', 'responses', 'EU 27', 'Belgium', 'Bulgaria',
#        'Czech Republic', 'Denmark', 'West_Germany', 'Germany', 'East_Germany',
#        'Estonia', 'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy',
#        'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta',
#        'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania', 'Slovenia',
#        'Slovakia', 'Finland', 'Sweden'],
#       dtype='object')

# %%
eurobarometer_sustainable_food.columns = eurobarometer_sustainable_food.columns.str.lower()
eurobarometer_sustainable_food.columns = eurobarometer_sustainable_food.columns.str.replace('-','_')
eurobarometer_sustainable_food.columns = eurobarometer_sustainable_food.columns.str.replace(' ','_')
eurobarometer_sustainable_food.drop(['west_germany', 'east_germany'], axis=1, inplace=True)

# %%
eurobarometer_sustainable_food.columns
# Out:
# Index(['questions', 'responses', 'eu_27', 'belgium', 'bulgaria',
#        'czech_republic', 'denmark', 'germany', 'estonia', 'ireland', 'greece',
#        'spain', 'france', 'croatia', 'italy', 'cyprus', 'latvia', 'lithuania',
#        'luxembourg', 'hungary', 'malta', 'netherlands', 'austria', 'poland',
#        'portugal', 'romania', 'slovenia', 'slovakia', 'finland', 'sweden'],
#       dtype='object')

# %% [markdown]
# # Step 7: Inspect Null Values / NaNs and datatypes with info()

# %%
# missing values detected (Belgium, Cyprus, Lithuania and the Netherlands one value each missing (replace with 0))
#eurobarometer_sustainable_food = eurobarometer_sustainable_food.replace('NaN',0, regex=True)
eurobarometer_sustainable_food = eurobarometer_sustainable_food.fillna(0)

# %% [markdown]
# # Step 9: Change data types if necessary:

# %%
# Change number values from str to float(2)
eurobarometer_sustainable_food = eurobarometer_sustainable_food.apply(pd.to_numeric, errors='ignore')
eurobarometer_sustainable_food.iloc[:,2:] = eurobarometer_sustainable_food.iloc[:,2:].mul(100)
eurobarometer_sustainable_food.round(decimals = 2)
# Out:
#                                             questions  \
# 0   Q1. When you buy food, which of the following ...
# 1   Q1. When you buy food, which of the following ...
# 2   Q1. When you buy food, which of the following ...
# 3   Q1. When you buy food, which of the following ...
# 4   Q1. When you buy food, which of the following ...
# 5   Q1. When you buy food, which of the following ...
# 6   Q1. When you buy food, which of the following ...
# 7   Q1. When you buy food, which of the following ...
# 8   Q1. When you buy food, which of the following ...
# 9   Q1. When you buy food, which of the following ...
# 10  Q1. When you buy food, which of the following ...
# 11  Q1. When you buy food, which of the following ...
# 12  Q2. Which of the following do you consider to ...
# 13  Q2. Which of the following do you consider to ...
# 14  Q2. Which of the following do you consider to ...
# 15  Q2. Which of the following do you consider to ...
# ...

# %%
eurobarometer_sustainable_food.head()
# Out:
#                                            questions  \
# 0  Q1. When you buy food, which of the following ...
# 1  Q1. When you buy food, which of the following ...
# 2  Q1. When you buy food, which of the following ...
# 3  Q1. When you buy food, which of the following ...
# 4  Q1. When you buy food, which of the following ...
#
#                                            responses      eu_27    belgium  \
# 0  Your ethics and beliefs (whether the item comp...   6.847303   4.485219
# 1  Food safety (e.g. if there is a risk in eating...  19.363366  15.290520
# 2                                               Cost  15.970922  18.654434
# 3  Nutrient content (e.g. the amount of vitamins,...  11.363219  13.659531
# 4                                              Taste  17.252267  19.775739
#
#     bulgaria  czech_republic    denmark    germany    estonia    ireland  ...  \
# 0   1.702933        2.336904  10.958904  15.324165   4.619565   7.102502  ...
# ...
